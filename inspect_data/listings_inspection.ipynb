# %%
import pandas as pd

# %%
london_airbnb_listings=pd.read_csv(r'C:\Users\kpali\Documents\Projects\London_Airbnb_Search\listings.csv',delimiter = ',',encoding = 'utf-8')
london_airbnb_listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   13913   https://www.airbnb.com/rooms/13913  20221210143044   2022-12-11
# 1   15400   https://www.airbnb.com/rooms/15400  20221210143044   2022-12-12
# 2  172811  https://www.airbnb.com/rooms/172811  20221210143044   2022-12-10
# 3  173082  https://www.airbnb.com/rooms/173082  20221210143044   2022-12-11
# 4   42010   https://www.airbnb.com/rooms/42010  20221210143044   2022-12-11
#
#             source                                 name  \
# 0      city scrape  Holiday London DB Room Let-on going
# 1      city scrape  Bright Chelsea  Apartment. Chelsea!
# 2  previous scrape     Nice double bedroom in NW London
# 3      city scrape  The Residential Suite Above Gallery
# 4      city scrape             You Will Save Money Here
#
#                                          description  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
# ...

# %%
print(london_airbnb_listings.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
london_airbnb_listings = london_airbnb_listings[['name','neighbourhood_cleansed','room_type','accommodates','bedrooms','bathrooms_text','amenities',
'minimum_nights','maximum_nights','price','host_response_time','review_scores_value','listing_url']]
london_airbnb_listings.head()
# Out:
#                                   name  neighbourhood_cleansed  \
# 0  Holiday London DB Room Let-on going               Islington
# 1  Bright Chelsea  Apartment. Chelsea!  Kensington and Chelsea
# 2     Nice double bedroom in NW London                  Camden
# 3  The Residential Suite Above Gallery                 Hackney
# 4             You Will Save Money Here                  Barnet
#
#          room_type  accommodates  bedrooms bathrooms_text  \
# 0     Private room             1       1.0  1 shared bath
# 1  Entire home/apt             2       1.0         1 bath
# 2  Entire home/apt             2       2.0            NaN
# 3  Entire home/apt             3       1.0      1.5 baths
# 4     Private room             2       1.0  1 shared bath
#
#                                            amenities  minimum_nights  \
# 0  ["Board games", "Conditioner", "Freezer", "Sho...               1
# 1  ["Smoke alarm", "Long term stays allowed", "Wa...              10
# ...

# %%
print(london_airbnb_listings.dtypes)
print(london_airbnb_listings.shape)
print((london_airbnb_listings.isnull().any(axis = 1)).sum())
print(london_airbnb_listings.duplicated().sum())
# Out:
# name                       object
# neighbourhood_cleansed     object
# room_type                  object
# accommodates                int64
# bedrooms                  float64
# bathrooms_text             object
# amenities                  object
# minimum_nights              int64
# maximum_nights              int64
# price                      object
# host_response_time         object
# review_scores_value       float64
# listing_url                object
# dtype: object
# (71938, 13)
# 37645
# 0

# %%
london_airbnb_listings.to_csv('../listings.csv',index = False)
